# %%
# !pip install -q -U langchain langchain-google-genai

# %%
import os
import getpass

if "GOOGLE_API_KEY" not in os.environ:
    os.environ["GOOGLE_API_KEY"] = getpass.getpass("Enter your Gemini API key: ")

# %%
# Import required libraries

from langchain.agents import create_agent
from langchain.tools import tool
from langchain_google_genai import ChatGoogleGenerativeAI
from IPython.display import Markdown, display

# %%
# Define a simple tool for task decomposition

@tool
def split_event_tasks(user_request: str) -> str:
    """Break the college fest request into planning subtasks."""

    tasks = [
        "Venue booking",
        "Catering",
        "Publicity",
        "Scheduling",
        "Volunteer allocation",
        "Permissions",
        "Budget planning"
    ]

    text = user_request.lower()

    if "technical" in text:
        tasks.append("Projector and internet setup")

    if "cultural" in text:
        tasks.append("Stage and sound arrangement")

    result = "Main subtasks:\n"
    for i, task in enumerate(tasks, 1):
        result += f"{i}. {task}\n"

    return result

# %%
# Initialize the Gemini language model

llm = ChatGoogleGenerativeAI(
    model="gemini-2.5-flash",
    temperature=0.3
)

# %%
# Create the Event Planner Agent using LangChain

agent = create_agent(
    model=llm,
    tools=[split_event_tasks],
    system_prompt="""
You are an Event Planner Agent.

First use the available tool to split the user's request into subtasks.
Then prepare a structured college fest plan.

Give the final answer under these headings:
1. Event Summary
2. Task Breakdown
3. Suggested Plan
4. Risks and Precautions
5. Final Checklist
"""
)

# %%
# Define a helper function to extract plain text from the model output

def extract_text(output):
    if isinstance(output, str):
        return output
    elif isinstance(output, list):
        text_parts = []
        for item in output:
            if isinstance(item, dict) and "text" in item:
                text_parts.append(item["text"])
        return "\n".join(text_parts)
    else:
        return str(output)

# %%
# Provide the event planning request

query = """
Plan a one-day college fest for 300 students with technical events,
cultural events, food stalls, volunteer teams, and a simple budget outline.
"""

# %%
# Run the Event Planner Agent on the given query

result = agent.invoke({
    "messages": [
        {"role": "user", "content": query}
    ]
})

# %%
final_answer = extract_text(result['messages'][-1].content)

# Display the final answer in a neat markdown format

display(Markdown(final_answer))
# Out:
# ## 1. Event Summary
#
# *   **Event Name:** Innovision Fest 2024
# *   **Date:** One Day (e.g., Saturday, October 26, 2024)
# *   **Attendees:** 300 students
# *   **Objective:** To provide a vibrant platform for students to showcase their technical and cultural talents, foster community spirit, and offer an enjoyable experience through diverse events and food.
# *   **Key Attractions:** Technical Competitions, Cultural Performances, Variety of Food Stalls.
#
# ## 2. Task Breakdown
#
# The planning of Innovision Fest 2024 can be broken down into the following key subtasks:
#
# **A. Planning & Coordination**
# *   Define event theme, name, and overall vision.
# *   Form a core organizing committee with leads for technical, cultural, logistics, finance, and publicity.
# *   Obtain all necessary permissions from college authorities.
# *   Set a comprehensive budget and financial targets.
#
# **B. Venue & Logistics**
# ...
